# %%
import pandas as pd
import numpy as np

# %%
networkdata = pd.read_excel("Edges board members to companys everything.xlsx")

# %%
networkdatapro = pd.get_dummies(networkdata["Who"]).groupby(networkdata["Where"]).apply(max)

# %%
networkdatapro.head()
# Out:
#                               (JR) Emanuelle Lino Saputo  25 NOMINEES LIMITED  \
# Where
# (Y.Z)QUEENCO LIMITED                                   0                    0
# 01 COMMUNIQUE LABORATORY INC                           0                    0
# 01CYBERATON PROENERGY SA                               0                    0
# 09WOMEN CO.,LTD.                                       0                    0
# 1-800 FLOWERS.COM, INC.                                0                    0
#
#                               7 CAPITAL  7 Capital sprl  A George Matthew  \
# Where
# (Y.Z)QUEENCO LIMITED                  0               0                 0
# 01 COMMUNIQUE LABORATORY INC          0               0                 0
# 01CYBERATON PROENERGY SA              0               0                 0
# 09WOMEN CO.,LTD.                      0               0                 0
# 1-800 FLOWERS.COM, INC.               0               0                 0
#
# ...

# %%
networkdatapro.to_csv('networkdatapro4.csv', sep = ";")
